# %% [markdown]
# **Difference between two lists**
#
# Given two list of numbers, write a Python program to print the difference between the two lists.
#
# Input Format
# The first line of input contains the size and elements of the List1.
#
# Second line of input contains the size and elements of the List2
#
# Output Format
# Print the difference between the two lists.
#
# Example 1
#
# Input
#
# 7
# 10 15 20 25 30 35 40
# 3
# 25 40 35
#
# Output
#
# 10 20 30 15
#
# Example 2
#
# Input
#
# 2
# 2 3
# 2
# 2 3
#
# Output
# ()

# %%
if __name__ == "__main__":
      #Your code here
      list1_size = int(input())
      list1 = list(map(int, input().split()))
      list2_size = int(input())
      list2 = list(map(int, input().split()))
      ans = [x for x in list1 if x not in list2]
      print(*ans)
# Out:
# 5
